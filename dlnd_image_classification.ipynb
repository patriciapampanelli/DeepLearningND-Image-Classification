# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
def print_first_sample_each_class(X, y, index=0, class_id=0):
    import matplotlib.pyplot as plt
    import matplotlib.image as mpimg
    import numpy as np
    import helper
    
    n_samples=[]
    plt.figure(figsize=(15, 30))
    
    # How many unique classes/labels there are in the dataset.
    n_classes = np.size(np.unique(y))
    
    classes = helper._load_label_names()
#     print(classes)
    
    for i in np.unique(y):
        plt.subplot(15, 5, i+1)
        x_selected = X[y == i]
        plt.imshow(x_selected[index, :, :, :])
        plt.title(classes[i])
        plt.axis('off')
        n_samples.append(len(x_selected))
    plt.show()

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
# helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)

batch_ids = list(range(1, 6))

features, labels = helper.load_cfar10_batch(cifar10_dataset_folder_path, batch_id)

print_first_sample_each_class(X=features, y=labels, class_id=0, index=1)

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    return  np.array(x / 255)

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x, n_values = 10):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    from sklearn.preprocessing import OneHotEncoder
    encoder = OneHotEncoder(n_values = n_values)    
    one_hot_encoded_labels = encoder.fit_transform(np.array(x).reshape(-1, 1)).toarray()
    return one_hot_encoded_labels

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %%
def shuffleTrainingData(X, y):
    from sklearn.utils import shuffle
    return shuffle(X, y)

valid_features, valid_labels = shuffleTrainingData(X = valid_features, y = valid_labels)

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    return tf.placeholder(tf.float32, (None, image_shape[0], image_shape[1], image_shape[2]), name = 'x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    return tf.placeholder(tf.int32, (None, n_classes), name = 'y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name="keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # tf.truncated_normal
    # https://www.tensorflow.org/api_docs/python/tf/truncated_normal
    
    # SOLUTION: Layer: Convolutional.
    conv_num_inputs = x_tensor.get_shape().as_list()[3]
    conv_W = tf.Variable(tf.truncated_normal([conv_ksize[0],
                                              conv_ksize[1],
                                              x_tensor.get_shape().as_list()[-1], 
                                              conv_num_outputs]))
    conv_b = tf.Variable(tf.zeros(conv_num_outputs))
    
    conv_strides = [1, conv_strides[0], conv_strides[1], 1]
    conv   = tf.nn.conv2d(x_tensor, conv_W, strides=conv_strides, padding='SAME') + conv_b

    # SOLUTION: Activation.
    conv = tf.nn.relu(conv)

    # SOLUTION: Pooling.
    conv = tf.nn.max_pool(conv, ksize=[1, pool_ksize[0], pool_ksize[1], 1], strides=[1, pool_strides[0], pool_strides[1], 1], padding='SAME')
    
    return conv 

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    from tensorflow.contrib.layers import flatten
    
    return flatten(x_tensor)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # SOLUTION: Fully Connected.
    width = x_tensor.get_shape().as_list()[1]
    fc_W  = tf.Variable(tf.truncated_normal(shape=[width, num_outputs]))
    fc_b  = tf.Variable(tf.zeros(num_outputs))
    fc    = tf.matmul(x_tensor, fc_W) + fc_b
    
    return fc


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # SOLUTION: Layer 5: Fully Connected. Input = 84. Output = 43.
    width = x_tensor.get_shape().as_list()[1]
    fc_W  = tf.Variable(tf.truncated_normal(shape=[width, num_outputs]))
    fc_b  = tf.Variable(tf.zeros(num_outputs))
    logits = tf.matmul(x_tensor, fc_W) + fc_b
    return logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    layer = conv2d_maxpool(x, 
                           conv_num_outputs=64, 
                           conv_ksize=[5, 5], 
                           conv_strides=[1, 1], 
                           pool_ksize=[3, 3],
                           pool_strides=[2, 2])
    
    layer = conv2d_maxpool(layer, 
                           conv_num_outputs=256, 
                           conv_ksize=[5, 5], 
                           conv_strides=[1, 1], 
                           pool_ksize=[3, 3],
                           pool_strides=[2, 2])
    
#     layer = conv2d_maxpool(layer, 
#                            conv_num_outputs=512, 
#                            conv_ksize=[5, 5], 
#                            conv_strides=[1, 1], 
#                            pool_ksize=[3, 3],
#                            pool_strides=[2, 2])

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    
    layer = flatten(layer)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    layer = fully_conn(layer, 240)
    layer = fully_conn(layer, 80)
    layer = fully_conn(layer, 40)
    
    layer = tf.nn.dropout(layer, keep_prob)
    
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    layer = output(layer, 10)
    
    
    # TODO: return output
    return layer


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # Implement Function
    session.run(optimizer, feed_dict={x: feature_batch,
                                      y: label_batch,
                                      keep_prob: keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    
#     valid_features_, valid_labels_ = shuffleTrainingData(X = valid_features, y = valid_labels)
    
    # Calculate batch loss and accuracy
    loss = sess.run(cost, feed_dict={x: feature_batch,
                                     y: label_batch,
                                     keep_prob: 1.})
    valid_acc = sess.run(accuracy, feed_dict={x: valid_features,
                                              y: valid_labels,
                                              keep_prob: 1.})
    
    
    print(' Loss : {} '.format(loss))
    print(' Validation Accuracy : {} '.format(valid_acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# Tune Parameters
epochs = 50
batch_size = 512
keep_probability = 0.77

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')


config = tf.ConfigProto()
config.gpu_options.allocator_type = 'BFC'
with tf.Session(config = config) as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())

    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:   Loss : 2316934.5
#  Validation Accuracy : 0.155799999833107
# Epoch  2, CIFAR-10 Batch 1:   Loss : 1206602.25
#  Validation Accuracy : 0.22619996964931488
# Epoch  3, CIFAR-10 Batch 1:   Loss : 955773.0625
#  Validation Accuracy : 0.257999986410141
# Epoch  4, CIFAR-10 Batch 1:   Loss : 785269.5625
#  Validation Accuracy : 0.28780001401901245
# Epoch  5, CIFAR-10 Batch 1:   Loss : 714422.0625
#  Validation Accuracy : 0.29899999499320984
# Epoch  6, CIFAR-10 Batch 1:   Loss : 657628.0
#  Validation Accuracy : 0.31439998745918274
# Epoch  7, CIFAR-10 Batch 1:   Loss : 584825.1875
#  Validation Accuracy : 0.33059996366500854
# Epoch  8, CIFAR-10 Batch 1:   Loss : 514011.40625
#  Validation Accuracy : 0.34119999408721924
# Epoch  9, CIFAR-10 Batch 1:   Loss : 479915.34375
#  Validation Accuracy : 0.3460000157356262
# Epoch 10, CIFAR-10 Batch 1:   Loss : 443801.8125
#  Validation Accuracy : 0.3633999824523926
# Epoch 11, CIFAR-10 Batch 1:   Loss : 425872.0
#  Validation Accuracy : 0.36959999799728394
# Epoch 12, CIFAR-10 Batch 1:   Loss : 385266.84375
#  Validation Accuracy : 0.37700000405311584
# Epoch 13, CIFAR-10 Batch 1:   Loss : 395175.0
#  Validation Accuracy : 0.37359997630119324
# Epoch 14, CIFAR-10 Batch 1:   Loss : 376116.0
#  Validation Accuracy : 0.3863999843597412
# Epoch 15, CIFAR-10 Batch 1:   Loss : 303655.09375
#  Validation Accuracy : 0.3912000060081482
# Epoch 16, CIFAR-10 Batch 1:   Loss : 296859.5625
#  Validation Accuracy : 0.3973999619483948
# Epoch 17, CIFAR-10 Batch 1:   Loss : 282239.46875
#  Validation Accuracy : 0.39059996604919434
# Epoch 18, CIFAR-10 Batch 1:   Loss : 276730.46875
#  Validation Accuracy : 0.39659997820854187
# Epoch 19, CIFAR-10 Batch 1:   Loss : 252137.375
#  Validation Accuracy : 0.39979997277259827
# Epoch 20, CIFAR-10 Batch 1:   Loss : 251697.875
#  Validation Accuracy : 0.3885999619960785
# Epoch 21, CIFAR-10 Batch 1:   Loss : 247896.921875
#  Validation Accuracy : 0.39239999651908875
# Epoch 22, CIFAR-10 Batch 1:   Loss : 220785.59375
#  Validation Accuracy : 0.40379998087882996
# Epoch 23, CIFAR-10 Batch 1:   Loss : 221548.140625
#  Validation Accuracy : 0.4034000039100647
# Epoch 24, CIFAR-10 Batch 1:   Loss : 229942.515625
#  Validation Accuracy : 0.40039998292922974
# Epoch 25, CIFAR-10 Batch 1:   Loss : 199502.125
#  Validation Accuracy : 0.4139999747276306
# Epoch 26, CIFAR-10 Batch 1:   Loss : 174639.15625
#  Validation Accuracy : 0.4253999590873718
# Epoch 27, CIFAR-10 Batch 1:   Loss : 157986.09375
#  Validation Accuracy : 0.43919995427131653
# Epoch 28, CIFAR-10 Batch 1:   Loss : 157989.375
#  Validation Accuracy : 0.43119996786117554
# Epoch 29, CIFAR-10 Batch 1:   Loss : 161700.109375
#  Validation Accuracy : 0.4300000071525574
# Epoch 30, CIFAR-10 Batch 1:   Loss : 138351.0
#  Validation Accuracy : 0.4359999895095825
# Epoch 31, CIFAR-10 Batch 1:   Loss : 122122.0
#  Validation Accuracy : 0.45219993591308594
# Epoch 32, CIFAR-10 Batch 1:   Loss : 117176.3515625
#  Validation Accuracy : 0.45799994468688965
# Epoch 33, CIFAR-10 Batch 1:   Loss : 111224.734375
#  Validation Accuracy : 0.45159998536109924
# Epoch 34, CIFAR-10 Batch 1:   Loss : 102661.7890625
#  Validation Accuracy : 0.45239999890327454
# Epoch 35, CIFAR-10 Batch 1:   Loss : 96792.796875
#  Validation Accuracy : 0.4551999568939209
# Epoch 36, CIFAR-10 Batch 1:   Loss : 100445.3125
#  Validation Accuracy : 0.4543999433517456
# Epoch 37, CIFAR-10 Batch 1:   Loss : 91047.0
#  Validation Accuracy : 0.46000000834465027
# Epoch 38, CIFAR-10 Batch 1:   Loss : 88750.6796875
#  Validation Accuracy : 0.4549999535083771
# Epoch 39, CIFAR-10 Batch 1:   Loss : 83343.3046875
#  Validation Accuracy : 0.4649999439716339
# Epoch 40, CIFAR-10 Batch 1:   Loss : 75227.453125
#  Validation Accuracy : 0.465999960899353
# Epoch 41, CIFAR-10 Batch 1:   Loss : 76432.28125
#  Validation Accuracy : 0.4577999413013458
# Epoch 42, CIFAR-10 Batch 1:   Loss : 76201.2578125
#  Validation Accuracy : 0.46939998865127563
# Epoch 43, CIFAR-10 Batch 1:   Loss : 86528.90625
#  Validation Accuracy : 0.4405999779701233
# Epoch 44, CIFAR-10 Batch 1:   Loss : 64769.08203125
#  Validation Accuracy : 0.46219995617866516
# Epoch 45, CIFAR-10 Batch 1:   Loss : 70984.078125
#  Validation Accuracy : 0.46279996633529663
# Epoch 46, CIFAR-10 Batch 1:   Loss : 62871.47265625
#  Validation Accuracy : 0.4681999087333679
# Epoch 47, CIFAR-10 Batch 1:   Loss : 54120.09765625
#  Validation Accuracy : 0.47519996762275696
# Epoch 48, CIFAR-10 Batch 1:   Loss : 54761.01171875
#  Validation Accuracy : 0.4723999500274658
# Epoch 49, CIFAR-10 Batch 1:   Loss : 53035.46875
#  Validation Accuracy : 0.46919992566108704
# Epoch 50, CIFAR-10 Batch 1:   Loss : 51382.77734375
#  Validation Accuracy : 0.4765999913215637

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:   Loss : 1614199.875
#  Validation Accuracy : 0.1671999841928482
# Epoch  1, CIFAR-10 Batch 2:   Loss : 1167971.375
#  Validation Accuracy : 0.23279999196529388
# Epoch  1, CIFAR-10 Batch 3:   Loss : 809208.625
#  Validation Accuracy : 0.2667999863624573
# Epoch  1, CIFAR-10 Batch 4:   Loss : 730932.9375
#  Validation Accuracy : 0.2777999937534332
# Epoch  1, CIFAR-10 Batch 5:   Loss : 661801.375
#  Validation Accuracy : 0.30639997124671936
# Epoch  2, CIFAR-10 Batch 1:   Loss : 612049.1875
#  Validation Accuracy : 0.31139999628067017
# Epoch  2, CIFAR-10 Batch 2:   Loss : 601097.375
#  Validation Accuracy : 0.32019996643066406
# Epoch  2, CIFAR-10 Batch 3:   Loss : 473533.96875
#  Validation Accuracy : 0.33739998936653137
# Epoch  2, CIFAR-10 Batch 4:   Loss : 470421.6875
#  Validation Accuracy : 0.3463999629020691
# Epoch  2, CIFAR-10 Batch 5:   Loss : 514861.65625
#  Validation Accuracy : 0.3503999710083008
# Epoch  3, CIFAR-10 Batch 1:   Loss : 455602.90625
#  Validation Accuracy : 0.3669999837875366
# Epoch  3, CIFAR-10 Batch 2:   Loss : 449572.125
#  Validation Accuracy : 0.3659999668598175
# Epoch  3, CIFAR-10 Batch 3:   Loss : 368349.78125
#  Validation Accuracy : 0.38259997963905334
# Epoch  3, CIFAR-10 Batch 4:   Loss : 358024.8125
#  Validation Accuracy : 0.3823999762535095
# Epoch  3, CIFAR-10 Batch 5:   Loss : 359232.90625
#  Validation Accuracy : 0.40119999647140503
# Epoch  4, CIFAR-10 Batch 1:   Loss : 361766.75
#  Validation Accuracy : 0.4063999652862549
# Epoch  4, CIFAR-10 Batch 2:   Loss : 372466.1875
#  Validation Accuracy : 0.4079999625682831
# Epoch  4, CIFAR-10 Batch 3:   Loss : 318837.875
#  Validation Accuracy : 0.41419997811317444
# Epoch  4, CIFAR-10 Batch 4:   Loss : 294516.5
#  Validation Accuracy : 0.421999990940094
# Epoch  4, CIFAR-10 Batch 5:   Loss : 297820.5625
#  Validation Accuracy : 0.4203999638557434
# Epoch  5, CIFAR-10 Batch 1:   Loss : 297020.0625
#  Validation Accuracy : 0.4339999854564667
# Epoch  5, CIFAR-10 Batch 2:   Loss : 287623.25
#  Validation Accuracy : 0.4267999827861786
# Epoch  5, CIFAR-10 Batch 3:   Loss : 259698.109375
#  Validation Accuracy : 0.4309999942779541
# Epoch  5, CIFAR-10 Batch 4:   Loss : 238573.859375
#  Validation Accuracy : 0.44979995489120483
# Epoch  5, CIFAR-10 Batch 5:   Loss : 238468.90625
#  Validation Accuracy : 0.4471999704837799
# Epoch  6, CIFAR-10 Batch 1:   Loss : 248774.3125
#  Validation Accuracy : 0.4503999948501587
# Epoch  6, CIFAR-10 Batch 2:   Loss : 240489.28125
#  Validation Accuracy : 0.43639999628067017
# Epoch  6, CIFAR-10 Batch 3:   Loss : 221475.765625
#  Validation Accuracy : 0.4545999765396118
# Epoch  6, CIFAR-10 Batch 4:   Loss : 206070.15625
#  Validation Accuracy : 0.464199960231781
# Epoch  6, CIFAR-10 Batch 5:   Loss : 194867.328125
#  Validation Accuracy : 0.46619999408721924
# Epoch  7, CIFAR-10 Batch 1:   Loss : 214115.0
#  Validation Accuracy : 0.46119990944862366
# Epoch  7, CIFAR-10 Batch 2:   Loss : 206146.625
#  Validation Accuracy : 0.4583999812602997
# Epoch  7, CIFAR-10 Batch 3:   Loss : 200946.265625
#  Validation Accuracy : 0.46619999408721924
# Epoch  7, CIFAR-10 Batch 4:   Loss : 192377.359375
#  Validation Accuracy : 0.47199997305870056
# Epoch  7, CIFAR-10 Batch 5:   Loss : 170393.125
#  Validation Accuracy : 0.4715999960899353
# Epoch  8, CIFAR-10 Batch 1:   Loss : 184572.65625
#  Validation Accuracy : 0.48059993982315063
# Epoch  8, CIFAR-10 Batch 2:   Loss : 174884.125
#  Validation Accuracy : 0.47819992899894714
# Epoch  8, CIFAR-10 Batch 3:   Loss : 175614.875
#  Validation Accuracy : 0.4821999669075012
# Epoch  8, CIFAR-10 Batch 4:   Loss : 175903.59375
#  Validation Accuracy : 0.4777999818325043
# Epoch  8, CIFAR-10 Batch 5:   Loss : 151649.5625
#  Validation Accuracy : 0.47599995136260986
# Epoch  9, CIFAR-10 Batch 1:   Loss : 163790.015625
#  Validation Accuracy : 0.4861999750137329
# Epoch  9, CIFAR-10 Batch 2:   Loss : 151130.15625
#  Validation Accuracy : 0.48079997301101685
# Epoch  9, CIFAR-10 Batch 3:   Loss : 163350.4375
#  Validation Accuracy : 0.48659995198249817
# Epoch  9, CIFAR-10 Batch 4:   Loss : 145860.515625
#  Validation Accuracy : 0.49219998717308044
# Epoch  9, CIFAR-10 Batch 5:   Loss : 130180.6484375
#  Validation Accuracy : 0.48399999737739563
# Epoch 10, CIFAR-10 Batch 1:   Loss : 150208.125
#  Validation Accuracy : 0.4817999303340912
# Epoch 10, CIFAR-10 Batch 2:   Loss : 156404.984375
#  Validation Accuracy : 0.4843999147415161
# Epoch 10, CIFAR-10 Batch 3:   Loss : 130181.609375
#  Validation Accuracy : 0.5025999546051025
# Epoch 10, CIFAR-10 Batch 4:   Loss : 130650.046875
#  Validation Accuracy : 0.5091999173164368
# Epoch 10, CIFAR-10 Batch 5:   Loss : 116586.8359375
#  Validation Accuracy : 0.4943999648094177
# Epoch 11, CIFAR-10 Batch 1:   Loss : 138149.03125
#  Validation Accuracy : 0.5019999742507935
# Epoch 11, CIFAR-10 Batch 2:   Loss : 119461.421875
#  Validation Accuracy : 0.504599928855896
# Epoch 11, CIFAR-10 Batch 3:   Loss : 121418.046875
#  Validation Accuracy : 0.500999927520752
# Epoch 11, CIFAR-10 Batch 4:   Loss : 120656.734375
#  Validation Accuracy : 0.5071999430656433
# Epoch 11, CIFAR-10 Batch 5:   Loss : 109320.59375
#  Validation Accuracy : 0.4983999729156494
# Epoch 12, CIFAR-10 Batch 1:   Loss : 123974.7890625
#  Validation Accuracy : 0.5005999207496643
# Epoch 12, CIFAR-10 Batch 2:   Loss : 112175.671875
#  Validation Accuracy : 0.4949999451637268
# Epoch 12, CIFAR-10 Batch 3:   Loss : 109199.1015625
#  Validation Accuracy : 0.5099999308586121
# Epoch 12, CIFAR-10 Batch 4:   Loss : 104986.484375
#  Validation Accuracy : 0.5183999538421631
# Epoch 12, CIFAR-10 Batch 5:   Loss : 93670.765625
#  Validation Accuracy : 0.5131999850273132
# Epoch 13, CIFAR-10 Batch 1:   Loss : 109356.59375
#  Validation Accuracy : 0.5117999315261841
# Epoch 13, CIFAR-10 Batch 2:   Loss : 98379.9140625
#  Validation Accuracy : 0.5011999607086182
# Epoch 13, CIFAR-10 Batch 3:   Loss : 101777.5
#  Validation Accuracy : 0.5165999531745911
# Epoch 13, CIFAR-10 Batch 4:   Loss : 94548.8203125
#  Validation Accuracy : 0.512999951839447
# Epoch 13, CIFAR-10 Batch 5:   Loss : 80479.5625
#  Validation Accuracy : 0.5209999680519104
# Epoch 14, CIFAR-10 Batch 1:   Loss : 100889.8515625
#  Validation Accuracy : 0.5209999084472656
# Epoch 14, CIFAR-10 Batch 2:   Loss : 92123.125
#  Validation Accuracy : 0.518799901008606
# Epoch 14, CIFAR-10 Batch 3:   Loss : 94302.1484375
#  Validation Accuracy : 0.5269999504089355
# Epoch 14, CIFAR-10 Batch 4:   Loss : 90804.953125
#  Validation Accuracy : 0.5141999125480652
# Epoch 14, CIFAR-10 Batch 5:   Loss : 76117.703125
#  Validation Accuracy : 0.5243999361991882
# Epoch 15, CIFAR-10 Batch 1:   Loss : 93497.40625
#  Validation Accuracy : 0.5275999307632446
# Epoch 15, CIFAR-10 Batch 2:   Loss : 79960.2265625
#  Validation Accuracy : 0.5287999510765076
# Epoch 15, CIFAR-10 Batch 3:   Loss : 90745.7890625
#  Validation Accuracy : 0.5257999300956726
# Epoch 15, CIFAR-10 Batch 4:   Loss : 76734.9296875
#  Validation Accuracy : 0.535599946975708
# Epoch 15, CIFAR-10 Batch 5:   Loss : 68804.09375
#  Validation Accuracy : 0.5329999327659607
# Epoch 16, CIFAR-10 Batch 1:   Loss : 78453.796875
#  Validation Accuracy : 0.5311999320983887
# Epoch 16, CIFAR-10 Batch 2:   Loss : 73495.765625
#  Validation Accuracy : 0.530799925327301
# Epoch 16, CIFAR-10 Batch 3:   Loss : 76908.625
#  Validation Accuracy : 0.5313999652862549
# Epoch 16, CIFAR-10 Batch 4:   Loss : 69873.6328125
#  Validation Accuracy : 0.5335999727249146
# Epoch 16, CIFAR-10 Batch 5:   Loss : 64651.5
#  Validation Accuracy : 0.5387999415397644
# Epoch 17, CIFAR-10 Batch 1:   Loss : 76507.65625
#  Validation Accuracy : 0.5413999557495117
# Epoch 17, CIFAR-10 Batch 2:   Loss : 70402.3828125
#  Validation Accuracy : 0.5323999524116516
# Epoch 17, CIFAR-10 Batch 3:   Loss : 72716.9296875
#  Validation Accuracy : 0.5351999998092651
# Epoch 17, CIFAR-10 Batch 4:   Loss : 64959.2578125
#  Validation Accuracy : 0.5437999367713928
# Epoch 17, CIFAR-10 Batch 5:   Loss : 59601.48828125
#  Validation Accuracy : 0.5389999151229858
# Epoch 18, CIFAR-10 Batch 1:   Loss : 67787.625
#  Validation Accuracy : 0.5437999367713928
# Epoch 18, CIFAR-10 Batch 2:   Loss : 65457.3125
#  Validation Accuracy : 0.5417999625205994
# Epoch 18, CIFAR-10 Batch 3:   Loss : 63637.03125
#  Validation Accuracy : 0.5347999334335327
# Epoch 18, CIFAR-10 Batch 4:   Loss : 59210.0390625
#  Validation Accuracy : 0.5391998887062073
# Epoch 18, CIFAR-10 Batch 5:   Loss : 59431.70703125
#  Validation Accuracy : 0.539199948310852
# Epoch 19, CIFAR-10 Batch 1:   Loss : 57430.5859375
#  Validation Accuracy : 0.5505999326705933
# Epoch 19, CIFAR-10 Batch 2:   Loss : 60227.7421875
#  Validation Accuracy : 0.5467999577522278
# Epoch 19, CIFAR-10 Batch 3:   Loss : 53511.4375
#  Validation Accuracy : 0.5461999177932739
# Epoch 19, CIFAR-10 Batch 4:   Loss : 53652.265625
#  Validation Accuracy : 0.5473998785018921
# Epoch 19, CIFAR-10 Batch 5:   Loss : 52373.0859375
#  Validation Accuracy : 0.5449999570846558
# Epoch 20, CIFAR-10 Batch 1:   Loss : 59882.484375
#  Validation Accuracy : 0.545199990272522
# Epoch 20, CIFAR-10 Batch 2:   Loss : 55803.90625
#  Validation Accuracy : 0.550399899482727
# Epoch 20, CIFAR-10 Batch 3:   Loss : 52141.15625
#  Validation Accuracy : 0.5503999590873718
# Epoch 20, CIFAR-10 Batch 4:   Loss : 51346.421875
#  Validation Accuracy : 0.5577999353408813
# Epoch 20, CIFAR-10 Batch 5:   Loss : 47204.359375
#  Validation Accuracy : 0.5531998872756958
# Epoch 21, CIFAR-10 Batch 1:   Loss : 53344.01171875
#  Validation Accuracy : 0.5527999401092529
# Epoch 21, CIFAR-10 Batch 2:   Loss : 53561.18359375
#  Validation Accuracy : 0.5553999543190002
# Epoch 21, CIFAR-10 Batch 3:   Loss : 49717.515625
#  Validation Accuracy : 0.5493999123573303
# Epoch 21, CIFAR-10 Batch 4:   Loss : 47227.453125
#  Validation Accuracy : 0.5553998947143555
# Epoch 21, CIFAR-10 Batch 5:   Loss : 45156.1015625
#  Validation Accuracy : 0.5577999353408813
# Epoch 22, CIFAR-10 Batch 1:   Loss : 50289.8203125
#  Validation Accuracy : 0.547999918460846
# Epoch 22, CIFAR-10 Batch 2:   Loss : 48423.8125
#  Validation Accuracy : 0.5571999549865723
# Epoch 22, CIFAR-10 Batch 3:   Loss : 43344.1015625
#  Validation Accuracy : 0.5539999604225159
# Epoch 22, CIFAR-10 Batch 4:   Loss : 43347.80859375
#  Validation Accuracy : 0.5559999346733093
# Epoch 22, CIFAR-10 Batch 5:   Loss : 41047.8515625
#  Validation Accuracy : 0.5621999502182007
# Epoch 23, CIFAR-10 Batch 1:   Loss : 42354.90625
#  Validation Accuracy : 0.5579999685287476
# Epoch 23, CIFAR-10 Batch 2:   Loss : 44028.98046875
#  Validation Accuracy : 0.5605999231338501
# Epoch 23, CIFAR-10 Batch 3:   Loss : 42241.0625
#  Validation Accuracy : 0.5567999482154846
# Epoch 23, CIFAR-10 Batch 4:   Loss : 39785.86328125
#  Validation Accuracy : 0.5627999305725098
# Epoch 23, CIFAR-10 Batch 5:   Loss : 37274.01171875
#  Validation Accuracy : 0.5621999502182007
# Epoch 24, CIFAR-10 Batch 1:   Loss : 39025.5078125
#  Validation Accuracy : 0.5643999576568604
# Epoch 24, CIFAR-10 Batch 2:   Loss : 44076.78515625
#  Validation Accuracy : 0.5629999041557312
# Epoch 24, CIFAR-10 Batch 3:   Loss : 34921.9296875
#  Validation Accuracy : 0.561199963092804
# Epoch 24, CIFAR-10 Batch 4:   Loss : 36060.03125
#  Validation Accuracy : 0.5655999183654785
# Epoch 24, CIFAR-10 Batch 5:   Loss : 34485.375
#  Validation Accuracy : 0.5613999366760254
# Epoch 25, CIFAR-10 Batch 1:   Loss : 35771.28125
#  Validation Accuracy : 0.5651999115943909
# Epoch 25, CIFAR-10 Batch 2:   Loss : 37930.92578125
#  Validation Accuracy : 0.5663999319076538
# Epoch 25, CIFAR-10 Batch 3:   Loss : 35479.28125
#  Validation Accuracy : 0.5549998879432678
# Epoch 25, CIFAR-10 Batch 4:   Loss : 35086.203125
#  Validation Accuracy : 0.5657999515533447
# Epoch 25, CIFAR-10 Batch 5:   Loss : 34073.91796875
#  Validation Accuracy : 0.56659996509552
# Epoch 26, CIFAR-10 Batch 1:   Loss : 35099.91015625
#  Validation Accuracy : 0.5727999210357666
# Epoch 26, CIFAR-10 Batch 2:   Loss : 38310.1875
#  Validation Accuracy : 0.5657999515533447
# Epoch 26, CIFAR-10 Batch 3:   Loss : 31892.08203125
#  Validation Accuracy : 0.5687999129295349
# Epoch 26, CIFAR-10 Batch 4:   Loss : 31730.6484375
#  Validation Accuracy : 0.572999894618988
# Epoch 26, CIFAR-10 Batch 5:   Loss : 29654.224609375
#  Validation Accuracy : 0.5631999373435974
# Epoch 27, CIFAR-10 Batch 1:   Loss : 33907.640625
#  Validation Accuracy : 0.572399914264679
# Epoch 27, CIFAR-10 Batch 2:   Loss : 34058.6328125
#  Validation Accuracy : 0.5705999135971069
# Epoch 27, CIFAR-10 Batch 3:   Loss : 27923.015625
#  Validation Accuracy : 0.572399914264679
# Epoch 27, CIFAR-10 Batch 4:   Loss : 30726.07421875
#  Validation Accuracy : 0.5757999420166016
# Epoch 27, CIFAR-10 Batch 5:   Loss : 27248.49609375
#  Validation Accuracy : 0.5733999609947205
# Epoch 28, CIFAR-10 Batch 1:   Loss : 29976.015625
#  Validation Accuracy : 0.5753999352455139
# Epoch 28, CIFAR-10 Batch 2:   Loss : 32944.0546875
#  Validation Accuracy : 0.5699999332427979
# Epoch 28, CIFAR-10 Batch 3:   Loss : 28518.2578125
#  Validation Accuracy : 0.5645999312400818
# Epoch 28, CIFAR-10 Batch 4:   Loss : 27318.947265625
#  Validation Accuracy : 0.5725998878479004
# Epoch 28, CIFAR-10 Batch 5:   Loss : 25316.08203125
#  Validation Accuracy : 0.5751999616622925
# Epoch 29, CIFAR-10 Batch 1:   Loss : 28626.80859375
#  Validation Accuracy : 0.5757998824119568
# Epoch 29, CIFAR-10 Batch 2:   Loss : 32670.685546875
#  Validation Accuracy : 0.5679999589920044
# Epoch 29, CIFAR-10 Batch 3:   Loss : 24008.748046875
#  Validation Accuracy : 0.5793999433517456
# Epoch 29, CIFAR-10 Batch 4:   Loss : 26083.01171875
#  Validation Accuracy : 0.5791999101638794
# Epoch 29, CIFAR-10 Batch 5:   Loss : 22945.40625
#  Validation Accuracy : 0.5743999481201172
# Epoch 30, CIFAR-10 Batch 1:   Loss : 25889.298828125
#  Validation Accuracy : 0.5753998756408691
# Epoch 30, CIFAR-10 Batch 2:   Loss : 27611.07421875
#  Validation Accuracy : 0.5813999176025391
# Epoch 30, CIFAR-10 Batch 3:   Loss : 21147.9453125
#  Validation Accuracy : 0.5803999304771423
# Epoch 30, CIFAR-10 Batch 4:   Loss : 25195.517578125
#  Validation Accuracy : 0.5791999101638794
# Epoch 30, CIFAR-10 Batch 5:   Loss : 21397.658203125
#  Validation Accuracy : 0.5737998485565186
# Epoch 31, CIFAR-10 Batch 1:   Loss : 25141.8359375
#  Validation Accuracy : 0.5791999101638794
# Epoch 31, CIFAR-10 Batch 2:   Loss : 25332.80859375
#  Validation Accuracy : 0.5857999324798584
# Epoch 31, CIFAR-10 Batch 3:   Loss : 20839.58984375
#  Validation Accuracy : 0.5785999298095703
# Epoch 31, CIFAR-10 Batch 4:   Loss : 21479.052734375
#  Validation Accuracy : 0.5837999582290649
# Epoch 31, CIFAR-10 Batch 5:   Loss : 21110.22265625
#  Validation Accuracy : 0.5773999691009521
# Epoch 32, CIFAR-10 Batch 1:   Loss : 21717.19921875
#  Validation Accuracy : 0.5841999053955078
# Epoch 32, CIFAR-10 Batch 2:   Loss : 24163.810546875
#  Validation Accuracy : 0.5879999399185181
# Epoch 32, CIFAR-10 Batch 3:   Loss : 19397.8984375
#  Validation Accuracy : 0.5845999121665955
# Epoch 32, CIFAR-10 Batch 4:   Loss : 19210.703125
#  Validation Accuracy : 0.5849999189376831
# Epoch 32, CIFAR-10 Batch 5:   Loss : 18200.076171875
#  Validation Accuracy : 0.5819999575614929
# Epoch 33, CIFAR-10 Batch 1:   Loss : 19041.296875
#  Validation Accuracy : 0.5907999277114868
# Epoch 33, CIFAR-10 Batch 2:   Loss : 22699.048828125
#  Validation Accuracy : 0.5898000001907349
# Epoch 33, CIFAR-10 Batch 3:   Loss : 16670.3515625
#  Validation Accuracy : 0.5871999263763428
# Epoch 33, CIFAR-10 Batch 4:   Loss : 17672.904296875
#  Validation Accuracy : 0.5895999073982239
# Epoch 33, CIFAR-10 Batch 5:   Loss : 17234.4453125
#  Validation Accuracy : 0.5737999081611633
# Epoch 34, CIFAR-10 Batch 1:   Loss : 19516.078125
#  Validation Accuracy : 0.5781999230384827
# Epoch 34, CIFAR-10 Batch 2:   Loss : 19913.9609375
#  Validation Accuracy : 0.5861998796463013
# Epoch 34, CIFAR-10 Batch 3:   Loss : 15671.3193359375
#  Validation Accuracy : 0.5829999446868896
# Epoch 34, CIFAR-10 Batch 4:   Loss : 16692.650390625
#  Validation Accuracy : 0.5893999338150024
# Epoch 34, CIFAR-10 Batch 5:   Loss : 15728.515625
#  Validation Accuracy : 0.5797999501228333
# Epoch 35, CIFAR-10 Batch 1:   Loss : 16665.875
#  Validation Accuracy : 0.5871999263763428
# Epoch 35, CIFAR-10 Batch 2:   Loss : 20446.486328125
#  Validation Accuracy : 0.5895999073982239
# Epoch 35, CIFAR-10 Batch 3:   Loss : 14834.041015625
#  Validation Accuracy : 0.5881999135017395
# Epoch 35, CIFAR-10 Batch 4:   Loss : 16340.6025390625
#  Validation Accuracy : 0.5933998823165894
# Epoch 35, CIFAR-10 Batch 5:   Loss : 16418.23046875
#  Validation Accuracy : 0.5811999440193176
# Epoch 36, CIFAR-10 Batch 1:   Loss : 15861.068359375
#  Validation Accuracy : 0.5891999006271362
# Epoch 36, CIFAR-10 Batch 2:   Loss : 17418.203125
#  Validation Accuracy : 0.5875999331474304
# Epoch 36, CIFAR-10 Batch 3:   Loss : 13261.62109375
#  Validation Accuracy : 0.5905998945236206
# Epoch 36, CIFAR-10 Batch 4:   Loss : 14753.0322265625
#  Validation Accuracy : 0.5793998837471008
# Epoch 36, CIFAR-10 Batch 5:   Loss : 14011.33984375
#  Validation Accuracy : 0.5879999399185181
# Epoch 37, CIFAR-10 Batch 1:   Loss : 15012.919921875
#  Validation Accuracy : 0.58899986743927
# Epoch 37, CIFAR-10 Batch 2:   Loss : 16757.048828125
#  Validation Accuracy : 0.5907999277114868
# Epoch 37, CIFAR-10 Batch 3:   Loss : 11876.013671875
#  Validation Accuracy : 0.5863999128341675
# Epoch 37, CIFAR-10 Batch 4:   Loss : 13639.3525390625
#  Validation Accuracy : 0.5871999263763428
# Epoch 37, CIFAR-10 Batch 5:   Loss : 12694.11328125
#  Validation Accuracy : 0.5895999670028687
# Epoch 38, CIFAR-10 Batch 1:   Loss : 13299.1796875
#  Validation Accuracy : 0.5923998951911926
# Epoch 38, CIFAR-10 Batch 2:   Loss : 15750.720703125
#  Validation Accuracy : 0.5941998958587646
# Epoch 38, CIFAR-10 Batch 3:   Loss : 11659.65625
#  Validation Accuracy : 0.5949999094009399
# Epoch 38, CIFAR-10 Batch 4:   Loss : 12258.048828125
#  Validation Accuracy : 0.5841999650001526
# Epoch 38, CIFAR-10 Batch 5:   Loss : 12022.9892578125
#  Validation Accuracy : 0.5933998823165894
# Epoch 39, CIFAR-10 Batch 1:   Loss : 13113.376953125
#  Validation Accuracy : 0.5965999364852905
# Epoch 39, CIFAR-10 Batch 2:   Loss : 13645.416015625
#  Validation Accuracy : 0.5963999032974243
# Epoch 39, CIFAR-10 Batch 3:   Loss : 10819.2724609375
#  Validation Accuracy : 0.5921999216079712
# Epoch 39, CIFAR-10 Batch 4:   Loss : 11643.9580078125
#  Validation Accuracy : 0.578999936580658
# Epoch 39, CIFAR-10 Batch 5:   Loss : 11007.626953125
#  Validation Accuracy : 0.5957999229431152
# Epoch 40, CIFAR-10 Batch 1:   Loss : 12855.9501953125
#  Validation Accuracy : 0.5971999168395996
# Epoch 40, CIFAR-10 Batch 2:   Loss : 12807.904296875
#  Validation Accuracy : 0.5899999141693115
# Epoch 40, CIFAR-10 Batch 3:   Loss : 10356.53515625
#  Validation Accuracy : 0.5909999012947083
# Epoch 40, CIFAR-10 Batch 4:   Loss : 11413.076171875
#  Validation Accuracy : 0.5863999128341675
# Epoch 40, CIFAR-10 Batch 5:   Loss : 10757.9375
#  Validation Accuracy : 0.5835999250411987
# Epoch 41, CIFAR-10 Batch 1:   Loss : 11916.8515625
#  Validation Accuracy : 0.597399890422821
# Epoch 41, CIFAR-10 Batch 2:   Loss : 12336.3779296875
#  Validation Accuracy : 0.5952000021934509
# Epoch 41, CIFAR-10 Batch 3:   Loss : 9854.0576171875
#  Validation Accuracy : 0.5911999344825745
# Epoch 41, CIFAR-10 Batch 4:   Loss : 9789.505859375
#  Validation Accuracy : 0.5941998958587646
# Epoch 41, CIFAR-10 Batch 5:   Loss : 9484.619140625
#  Validation Accuracy : 0.5941998958587646
# Epoch 42, CIFAR-10 Batch 1:   Loss : 12149.7734375
#  Validation Accuracy : 0.5935999155044556
# Epoch 42, CIFAR-10 Batch 2:   Loss : 11993.3427734375
#  Validation Accuracy : 0.5961999297142029
# Epoch 42, CIFAR-10 Batch 3:   Loss : 8648.9296875
#  Validation Accuracy : 0.5979999303817749
# Epoch 42, CIFAR-10 Batch 4:   Loss : 9534.267578125
#  Validation Accuracy : 0.5875998735427856
# Epoch 42, CIFAR-10 Batch 5:   Loss : 8917.2861328125
#  Validation Accuracy : 0.5985999703407288
# Epoch 43, CIFAR-10 Batch 1:   Loss : 9897.4599609375
#  Validation Accuracy : 0.6001998782157898
# Epoch 43, CIFAR-10 Batch 2:   Loss : 11850.7236328125
#  Validation Accuracy : 0.596799910068512
# Epoch 43, CIFAR-10 Batch 3:   Loss : 7196.890625
#  Validation Accuracy : 0.598599910736084
# Epoch 43, CIFAR-10 Batch 4:   Loss : 8624.0654296875
#  Validation Accuracy : 0.5857999324798584
# Epoch 43, CIFAR-10 Batch 5:   Loss : 7851.77978515625
#  Validation Accuracy : 0.5971999168395996
# Epoch 44, CIFAR-10 Batch 1:   Loss : 9917.837890625
#  Validation Accuracy : 0.5987999439239502
# Epoch 44, CIFAR-10 Batch 2:   Loss : 10852.2333984375
#  Validation Accuracy : 0.596799910068512
# Epoch 44, CIFAR-10 Batch 3:   Loss : 6976.79345703125
#  Validation Accuracy : 0.5969998836517334
# Epoch 44, CIFAR-10 Batch 4:   Loss : 8876.9365234375
#  Validation Accuracy : 0.5819999575614929
# Epoch 44, CIFAR-10 Batch 5:   Loss : 8174.97802734375
#  Validation Accuracy : 0.5897998809814453
# Epoch 45, CIFAR-10 Batch 1:   Loss : 9514.458984375
#  Validation Accuracy : 0.59579998254776
# Epoch 45, CIFAR-10 Batch 2:   Loss : 10786.8515625
#  Validation Accuracy : 0.5963999032974243
# Epoch 45, CIFAR-10 Batch 3:   Loss : 6211.884765625
#  Validation Accuracy : 0.5973999500274658
# Epoch 45, CIFAR-10 Batch 4:   Loss : 7654.4833984375
#  Validation Accuracy : 0.5871999263763428
# Epoch 45, CIFAR-10 Batch 5:   Loss : 6837.53564453125
#  Validation Accuracy : 0.5963999032974243
# Epoch 46, CIFAR-10 Batch 1:   Loss : 8941.7080078125
#  Validation Accuracy : 0.6045998930931091
# Epoch 46, CIFAR-10 Batch 2:   Loss : 8446.458984375
#  Validation Accuracy : 0.5983998775482178
# Epoch 46, CIFAR-10 Batch 3:   Loss : 6306.7744140625
#  Validation Accuracy : 0.6053999066352844
# Epoch 46, CIFAR-10 Batch 4:   Loss : 7067.3388671875
#  Validation Accuracy : 0.5879999399185181
# Epoch 46, CIFAR-10 Batch 5:   Loss : 5972.4111328125
#  Validation Accuracy : 0.601599931716919
# Epoch 47, CIFAR-10 Batch 1:   Loss : 7427.2431640625
#  Validation Accuracy : 0.6061998605728149
# Epoch 47, CIFAR-10 Batch 2:   Loss : 8182.9873046875
#  Validation Accuracy : 0.5995998978614807
# Epoch 47, CIFAR-10 Batch 3:   Loss : 5060.005859375
#  Validation Accuracy : 0.6011998653411865
# Epoch 47, CIFAR-10 Batch 4:   Loss : 6266.3251953125
#  Validation Accuracy : 0.5911999344825745
# Epoch 47, CIFAR-10 Batch 5:   Loss : 6033.35986328125
#  Validation Accuracy : 0.5947998762130737
# Epoch 48, CIFAR-10 Batch 1:   Loss : 7316.412109375
#  Validation Accuracy : 0.5971999168395996
# Epoch 48, CIFAR-10 Batch 2:   Loss : 7783.30029296875
#  Validation Accuracy : 0.5933998823165894
# Epoch 48, CIFAR-10 Batch 3:   Loss : 5231.568359375
#  Validation Accuracy : 0.6043999195098877
# Epoch 48, CIFAR-10 Batch 4:   Loss : 6542.37744140625
#  Validation Accuracy : 0.5863999128341675
# Epoch 48, CIFAR-10 Batch 5:   Loss : 5779.70849609375
#  Validation Accuracy : 0.5913999676704407
# Epoch 49, CIFAR-10 Batch 1:   Loss : 7594.130859375
#  Validation Accuracy : 0.5981999635696411
# Epoch 49, CIFAR-10 Batch 2:   Loss : 7513.99462890625
#  Validation Accuracy : 0.5957999229431152
# Epoch 49, CIFAR-10 Batch 3:   Loss : 4982.3623046875
#  Validation Accuracy : 0.6027998924255371
# Epoch 49, CIFAR-10 Batch 4:   Loss : 5954.12841796875
#  Validation Accuracy : 0.5897999405860901
# Epoch 49, CIFAR-10 Batch 5:   Loss : 4943.0615234375
#  Validation Accuracy : 0.5983999371528625
# Epoch 50, CIFAR-10 Batch 1:   Loss : 6048.9560546875
#  Validation Accuracy : 0.600399911403656
# Epoch 50, CIFAR-10 Batch 2:   Loss : 6655.77392578125
#  Validation Accuracy : 0.6053999066352844
# Epoch 50, CIFAR-10 Batch 3:   Loss : 3670.871337890625
#  Validation Accuracy : 0.6047999262809753
# Epoch 50, CIFAR-10 Batch 4:   Loss : 5260.4140625
#  Validation Accuracy : 0.5943998694419861
# Epoch 50, CIFAR-10 Batch 5:   Loss : 4939.35693359375
#  Validation Accuracy : 0.5971999764442444

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.5892520666122436

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
